# %% [markdown]
# 1.What are the two values of the Boolean data type? How do you write them?
# Solution: The two values of Boolean data type is 'True' and 'false'.We use 'Bool' as data type and they are represented as T and F(both capital).
#
# 2. What are the three different types of Boolean operators?
# Solution: The three type of Boolean operators are AND, OR , NOT.
#
# 3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean
# values for the operator and what it evaluate).
# Solution: Following is the list:
#           True and True is True
#           True and False is Flase
#           False and True is False
#           False and False is False
#           True or True is True
#           True or False is True
#           False or True is True
#           False or False is False
#           not True is Flase
#           not False is True.
#
#
# 4. What are the values of the following expressions?
# (5 > 4) and (3 == 5)
# not (5 > 4)
# (5 > 4) or (3 == 5)
# not ((5 > 4) or (3 == 5))
# (True and True) and (True == False)
# (not False) or (not True)
#
# Solution:(5 > 4) and (3 == 5) is Flase
#
# not (5 > 4) is Flase
#
# (5 > 4) or (3 == 5) is True
#
# not ((5 > 4) or (3 == 5)) is False
#
# (True and True) and (True == False) is Flase
#
# (not False) or (not True) is True
#
#
# 5. What are the six comparison operators?
# Solution: Listing the comparison operators:
#            <, >, =, <=, >=, !=
#
# 6. How do you tell the difference between the equal to and assignment operators?Describe a
# condition and when you would use one.
# Solution: The difference between equal and assignment operator is Assignment operator use '=' and equal operator use '=='.
#           When we want to assign a value to a variable we use assignment operator and we want to compare two values to be
#           equal or it we use equal operator.
#
# 7. Identify the three blocks in this code:
# spam = 0
# if spam == 10:
# print('eggs')
# if spam > 5:
# print('bacon')
# else:
# print('ham')
# print('spam')
# print('spam')
#
# Solution: The three blocks are between the if statement which prints egg adn second bacon and last else part.
#
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints
# Greetings! if anything else is stored in spam.
# Solution: spam=0;
#           if spam ==1:
#           print('Hello')
#           elif spam==2 :
#           print('Howdy')
#           else:
#           print('Greetings!')
#
#
#
# 9.If your programme is stuck in an endless loop, what keys you’ll press?
# solution: Ctrl+c is pressed to exit a infinite loop.
#
# 10. How can you tell the difference between break and continue?
# Solution: Break statement terminate the whole loop when some action is against the condition whereas continue statement skip the current iteration and go to the next statement if any.
#
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
# Solution: All the three are same as range(10) call the range from 0-10(not including 10) same as range (0, 10) and range(0, 10, 1) tells about starting point, ending point with difference in both respectively giving same output.
#
# 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent
# program that prints the numbers 1 to 10 using a while loop.
# Solution: For i in range(1,11):
#           print i
#           i++
#           while i<11:
#           print i
#           I\i++
#
# 13. If you had a function named bacon() inside a module named spam, how would you call it after
# importing spam?
# Solution: spam.bacon() is correct way to represent.
